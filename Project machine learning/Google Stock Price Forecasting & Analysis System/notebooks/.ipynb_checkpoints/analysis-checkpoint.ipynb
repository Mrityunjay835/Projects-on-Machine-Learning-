# %% [markdown]
# # import important libraries

# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv('../data/Google_historical_data.csv')
df.head()
# Out:
#                         Date      Open      High       Low     Close  \
# 0  2004-08-19 00:00:00-04:00  2.483736  2.584576  2.383393  2.492181
# 1  2004-08-20 00:00:00-04:00  2.508822  2.709260  2.496155  2.690134
# 2  2004-08-23 00:00:00-04:00  2.750738  2.818544  2.708514  2.717207
# 3  2004-08-24 00:00:00-04:00  2.762908  2.771850  2.572406  2.604694
# 4  2004-08-25 00:00:00-04:00  2.606930  2.682435  2.580105  2.632761
#
#       Volume ticker                                   name
# 0  893181924  GOOGL  Alphabet Inc. (GOOGL) Historical Data
# 1  456686856  GOOGL  Alphabet Inc. (GOOGL) Historical Data
# 2  365122512  GOOGL  Alphabet Inc. (GOOGL) Historical Data
# 3  304946748  GOOGL  Alphabet Inc. (GOOGL) Historical Data
# 4  183772044  GOOGL  Alphabet Inc. (GOOGL) Historical Data

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5373 entries, 0 to 5372
# Data columns (total 8 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   Date    5373 non-null   object
#  1   Open    5373 non-null   float64
#  2   High    5373 non-null   float64
#  3   Low     5373 non-null   float64
#  4   Close   5373 non-null   float64
#  5   Volume  5373 non-null   int64
#  6   ticker  5373 non-null   object
#  7   name    5373 non-null   object
# dtypes: float64(4), int64(1), object(3)
# memory usage: 335.9+ KB

# %%
df.describe().T\
    .style.background_gradient(cmap='viridis')\
    .set_table_styles([{
        'selector': 'th', 
        'props': [('font-size', '12pt')]
        }]).\
        set_caption("Statistical Summary of Google Stock Data")
# Out:
# <style type="text/css">
# #T_f4322 th {
#   font-size: 12pt;
# }
# #T_f4322_row0_col0, #T_f4322_row0_col1, #T_f4322_row0_col2, #T_f4322_row0_col3, #T_f4322_row0_col4, #T_f4322_row0_col5, #T_f4322_row0_col6, #T_f4322_row0_col7, #T_f4322_row1_col0, #T_f4322_row1_col1, #T_f4322_row1_col2, #T_f4322_row1_col3, #T_f4322_row1_col4, #T_f4322_row1_col5, #T_f4322_row1_col6, #T_f4322_row1_col7, #T_f4322_row2_col0, #T_f4322_row2_col1, #T_f4322_row2_col2, #T_f4322_row2_col3, #T_f4322_row2_col4, #T_f4322_row2_col5, #T_f4322_row2_col6, #T_f4322_row2_col7, #T_f4322_row3_col0, #T_f4322_row3_col1, #T_f4322_row3_col2, #T_f4322_row3_col3, #T_f4322_row3_col4, #T_f4322_row3_col5, #T_f4322_row3_col6, #T_f4322_row3_col7, #T_f4322_row4_col0 {
#   background-color: #440154;
#   color: #f1f1f1;
# }
# #T_f4322_row4_col1, #T_f4322_row4_col2, #T_f4322_row4_col3, #T_f4322_row4_col4, #T_f4322_row4_col5, #T_f4322_row4_col6, #T_f4322_row4_col7 {
#   background-color: #fde725;
#   color: #000000;
# }
# </style>
# <table id="T_f4322">
#   <caption>Statistical Summary of Google Stock Data</caption>
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_f4322_level0_col0" class="col_heading level0 col0" >count</th>
#       <th id="T_f4322_level0_col1" class="col_heading level0 col1" >mean</th>
#       <th id="T_f4322_level0_col2" class="col_heading level0 col2" >std</th>
#       <th id="T_f4322_level0_col3" class="col_heading level0 col3" >min</th>
#       <th id="T_f4322_level0_col4" class="col_heading level0 col4" >25%</th>
#       <th id="T_f4322_level0_col5" class="col_heading level0 col5" >50%</th>
#       <th id="T_f4322_level0_col6" class="col_heading level0 col6" >75%</th>
#       <th id="T_f4322_level0_col7" class="col_heading level0 col7" >max</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_f4322_level0_row0" class="row_heading level0 row0" >Open</th>
#       <td id="T_f4322_row0_col0" class="data row0 col0" >5373.000000</td>
#       <td id="T_f4322_row0_col1" class="data row0 col1" >54.925057</td>
#       <td id="T_f4322_row0_col2" class="data row0 col2" >57.011319</td>
#       <td id="T_f4322_row0_col3" class="data row0 col3" >2.463617</td>
#       <td id="T_f4322_row0_col4" class="data row0 col4" >13.293948</td>
#       <td id="T_f4322_row0_col5" class="data row0 col5" >29.312309</td>
#       <td id="T_f4322_row0_col6" class="data row0 col6" >75.112966</td>
#       <td id="T_f4322_row0_col7" class="data row0 col7" >325.996755</td>
#     </tr>
#     <tr>
#       <th id="T_f4322_level0_row1" class="row_heading level0 row1" >High</th>
#       <td id="T_f4322_row1_col0" class="data row1 col0" >5373.000000</td>
#       <td id="T_f4322_row1_col1" class="data row1 col1" >55.520014</td>
#       <td id="T_f4322_row1_col2" class="data row1 col2" >57.675052</td>
#       <td id="T_f4322_row1_col3" class="data row1 col3" >2.526953</td>
#       <td id="T_f4322_row1_col4" class="data row1 col4" >13.398762</td>
#       <td id="T_f4322_row1_col5" class="data row1 col5" >29.501594</td>
#       <td id="T_f4322_row1_col6" class="data row1 col6" >75.883636</td>
#       <td id="T_f4322_row1_col7" class="data row1 col7" >328.615037</td>
#     </tr>
#     <tr>
#       <th id="T_f4322_level0_row2" class="row_heading level0 row2" >Low</th>
#       <td id="T_f4322_row2_col0" class="data row2 col0" >5373.000000</td>
#       <td id="T_f4322_row2_col1" class="data row2 col1" >54.337891</td>
#       <td id="T_f4322_row2_col2" class="data row2 col2" >56.361989</td>
#       <td id="T_f4322_row2_col3" class="data row2 col3" >2.383393</td>
#       <td id="T_f4322_row2_col4" class="data row2 col4" >13.154611</td>
#       <td id="T_f4322_row2_col5" class="data row2 col5" >29.114519</td>
#       <td id="T_f4322_row2_col6" class="data row2 col6" >74.571555</td>
#       <td id="T_f4322_row2_col7" class="data row2 col7" >318.961364</td>
#     </tr>
#     <tr>
#       <th id="T_f4322_level0_row3" class="row_heading level0 row3" >Close</th>
#       <td id="T_f4322_row3_col0" class="data row3 col0" >5373.000000</td>
#       <td id="T_f4322_row3_col1" class="data row3 col1" >54.943370</td>
#       <td id="T_f4322_row3_col2" class="data row3 col2" >57.037104</td>
#       <td id="T_f4322_row3_col3" class="data row3 col3" >2.483985</td>
#       <td id="T_f4322_row3_col4" class="data row3 col4" >13.278549</td>
#       <td id="T_f4322_row3_col5" class="data row3 col5" >29.317486</td>
#       <td id="T_f4322_row3_col6" class="data row3 col6" >75.243484</td>
#       <td id="T_f4322_row3_col7" class="data row3 col7" >323.228577</td>
#     </tr>
#     <tr>
#       <th id="T_f4322_level0_row4" class="row_heading level0 row4" >Volume</th>
#       <td id="T_f4322_row4_col0" class="data row4 col0" >5373.000000</td>
#       <td id="T_f4322_row4_col1" class="data row4 col1" >111987702.429927</td>
#       <td id="T_f4322_row4_col2" class="data row4 col2" >144523119.643200</td>
#       <td id="T_f4322_row4_col3" class="data row4 col3" >9312000.000000</td>
#       <td id="T_f4322_row4_col4" class="data row4 col4" >30290000.000000</td>
#       <td id="T_f4322_row4_col5" class="data row4 col5" >52670200.000000</td>
#       <td id="T_f4322_row4_col6" class="data row4 col6" >132303564.000000</td>
#       <td id="T_f4322_row4_col7" class="data row4 col7" >1643023332.000000</td>
#     </tr>
#   </tbody>
# </table>
