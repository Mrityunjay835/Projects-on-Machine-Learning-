# %%
import nltk

# Download required NLTK data (run once)
nltk.download('punkt')
nltk.download('wordnet')
nltk.download('omw-1.4')   # often needed with wordnet

from nltk.stem import WordNetLemmatizer
lemmatizer = WordNetLemmatizer()

import json
import pickle
import tensorflow
# Out:
# [nltk_data] Downloading package punkt to /home/mrityunjay/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# [nltk_data] Downloading package wordnet to
# [nltk_data]     /home/mrityunjay/nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!
# [nltk_data] Downloading package omw-1.4 to
# [nltk_data]     /home/mrityunjay/nltk_data...
# [nltk_data]   Package omw-1.4 is already up-to-date!
# 2025-12-04 18:56:01.856819: I external/local_tsl/tsl/cuda/cudart_stub.cc:31] Could not find cuda drivers on your machine, GPU will not be used.
# 2025-12-04 18:56:01.882132: E external/local_xla/xla/stream_executor/cuda/cuda_dnn.cc:9261] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# 2025-12-04 18:56:01.882155: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:607] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# 2025-12-04 18:56:01.883088: E external/local_xla/xla/stream_executor/cuda/cuda_blas.cc:1515] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# 2025-12-04 18:56:01.887500: I external/local_tsl/tsl/cuda/cudart_stub.cc:31] Could not find cuda drivers on your machine, GPU will not be used.
# 2025-12-04 18:56:01.887856: I tensorflow/core/platform/cpu_feature_guard.cc:182] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2025-12-04 18:56:02.448591: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT

# %%
import numpy as np
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, Dropout , Activation, Flatten , Conv2D, MaxPooling2D
from tensorflow.keras.optimizers import SGD
import random

# %%
words=[]
labels = []
docs = []
ignore_list = ['?', '!']

# %%
dataset = open('intents.json').read()
intents = json.loads(dataset)

# %%
for intent in intents['intents']:
    for pattern in intent['patterns']:

        #tokenize each word
        word_token = nltk.word_tokenize(pattern)
        words.extend(word_token)
        #add documents in the corpus
        docs.append((word_token, intent['tag']))

        # add to our labels list
        if intent['tag'] not in labels:
            labels.append(intent['tag'])

# %%
# lemmatize each word, and sort words by removing duplicates:
words = [lemmatizer.lemmatize(word.lower()) for word in words if word not in ignore_list]
words = sorted(list(set(words)))

# %%
# sort labels:
labels = sorted(list(set(labels)))

# %%
pickle.dump(words,open('words.pkl','wb'))
pickle.dump(labels,open('labels.pkl','wb'))

# %%
training_data = []
output = [0] * len(labels)

for doc in docs:
    bag_of_words = []
    pattern_words = doc[0]
    pattern_words = [lemmatizer.lemmatize(word.lower()) for word in pattern_words]
    
    for w in words:
        bag_of_words.append(1 if w in pattern_words else 0)
            
    output_row = list(output)
    output_row[labels.index(doc[1])] = 1
    
    training_data.append([bag_of_words, output_row])

# %%
# convert training_data to numpy array and shuffle the data:
random.shuffle(training_data)
# split into features and labels
x_train = []
y_train = []

for bag_of_words, output_row in training_data:
    x_train.append(bag_of_words)
    y_train.append(output_row)

x_train = np.array(x_train)
y_train = np.array(y_train)

# %%
print("x_train shape:", x_train.shape)
print("y_train shape:", y_train.shape)
# Out:
# x_train shape: (47, 88)
# y_train shape: (47, 9)

# %%
# Creating Model:

model = Sequential()
model.add(Dense(128, input_shape=(len(x_train[0]),), activation='relu'))
model.add(Dropout(0.5))
model.add(Dense(64, activation='relu'))
model.add(Dropout(0.5))
model.add(Dense(len(y_train[0]), activation='softmax'))
# Out:
# 2025-12-04 18:58:27.404796: I external/local_xla/xla/stream_executor/cuda/cuda_executor.cc:901] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2025-12-04 18:58:27.408691: W tensorflow/core/common_runtime/gpu/gpu_device.cc:2256] Cannot dlopen some GPU libraries. Please make sure the missing libraries mentioned above are installed properly if you would like to use GPU. Follow the guide at https://www.tensorflow.org/install/gpu for how to download and setup the required libraries for your platform.
# Skipping registering GPU devices...

# %%
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  dense (Dense)               (None, 128)               11392
#
#  dropout (Dropout)           (None, 128)               0
#
#  dense_1 (Dense)             (None, 64)                8256
#
#  dropout_1 (Dropout)         (None, 64)                0
#
#  dense_2 (Dense)             (None, 9)                 585
#
# =================================================================
# Total params: 20233 (79.04 KB)
# Trainable params: 20233 (79.04 KB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________

# %%
sgd_optimizer = SGD(learning_rate=0.01, momentum=0.9, nesterov=True)
model.compile(loss='categorical_crossentropy', optimizer=sgd_optimizer, metrics=['accuracy'])

# %%
# fit the model 
history = model.fit(np.array(x_train), np.array(y_train), epochs=200, batch_size=5, verbose=1)
# Out:
# Epoch 1/200
# 10/10 [==============================] - 0s 1ms/step - loss: 2.1748 - accuracy: 0.1702
# Epoch 2/200
# 10/10 [==============================] - 0s 736us/step - loss: 2.1756 - accuracy: 0.2128
# Epoch 3/200
# 10/10 [==============================] - 0s 712us/step - loss: 2.0810 - accuracy: 0.2553
# Epoch 4/200
# 10/10 [==============================] - 0s 806us/step - loss: 1.9956 - accuracy: 0.4043
# Epoch 5/200
# 10/10 [==============================] - 0s 809us/step - loss: 1.8870 - accuracy: 0.4894
# Epoch 6/200
# 10/10 [==============================] - 0s 753us/step - loss: 1.8612 - accuracy: 0.3404
# Epoch 7/200
# 10/10 [==============================] - 0s 795us/step - loss: 1.6268 - accuracy: 0.5106
# Epoch 8/200
# 10/10 [==============================] - 0s 727us/step - loss: 1.6084 - accuracy: 0.4894
# Epoch 9/200
# 10/10 [==============================] - 0s 732us/step - loss: 1.3857 - accuracy: 0.6596
# Epoch 10/200
# 10/10 [==============================] - 0s 815us/step - loss: 1.2896 - accuracy: 0.5957
# Epoch 11/200
# 10/10 [==============================] - 0s 667us/step - loss: 1.1670 - accuracy: 0.6809
# Epoch 12/200
# 10/10 [==============================] - 0s 724us/step - loss: 1.1178 - accuracy: 0.7021
# Epoch 13/200
# 10/10 [==============================] - 0s 739us/step - loss: 0.9556 - accuracy: 0.7021
# Epoch 14/200
# 10/10 [==============================] - 0s 693us/step - loss: 0.8532 - accuracy: 0.7234
# Epoch 15/200
# 10/10 [==============================] - 0s 793us/step - loss: 0.8476 - accuracy: 0.7660
# Epoch 16/200
# 10/10 [==============================] - 0s 729us/step - loss: 0.9250 - accuracy: 0.7021
# Epoch 17/200
# 10/10 [==============================] - 0s 698us/step - loss: 0.8537 - accuracy: 0.7447
# Epoch 18/200
# 10/10 [==============================] - 0s 713us/step - loss: 0.6524 - accuracy: 0.7872
# Epoch 19/200
# 10/10 [==============================] - 0s 724us/step - loss: 0.7634 - accuracy: 0.7447
# Epoch 20/200
# 10/10 [==============================] - 0s 725us/step - loss: 0.6282 - accuracy: 0.7660
# Epoch 21/200
# 10/10 [==============================] - 0s 790us/step - loss: 0.6005 - accuracy: 0.8936
# Epoch 22/200
# 10/10 [==============================] - 0s 742us/step - loss: 0.4290 - accuracy: 0.8936
# Epoch 23/200
# 10/10 [==============================] - 0s 664us/step - loss: 0.5219 - accuracy: 0.8085
# Epoch 24/200
# 10/10 [==============================] - 0s 785us/step - loss: 0.5132 - accuracy: 0.8085
# Epoch 25/200
# 10/10 [==============================] - 0s 750us/step - loss: 0.4488 - accuracy: 0.8723
# Epoch 26/200
# 10/10 [==============================] - 0s 745us/step - loss: 0.4800 - accuracy: 0.8085
# Epoch 27/200
# 10/10 [==============================] - 0s 790us/step - loss: 0.3481 - accuracy: 0.8936
# Epoch 28/200
# 10/10 [==============================] - 0s 763us/step - loss: 0.2977 - accuracy: 0.9149
# Epoch 29/200
# 10/10 [==============================] - 0s 741us/step - loss: 0.3780 - accuracy: 0.8511
# Epoch 30/200
# 10/10 [==============================] - 0s 733us/step - loss: 0.3539 - accuracy: 0.9362
# Epoch 31/200
# 10/10 [==============================] - 0s 645us/step - loss: 0.2047 - accuracy: 0.9787
# Epoch 32/200
# 10/10 [==============================] - 0s 792us/step - loss: 0.2348 - accuracy: 0.9574
# Epoch 33/200
# 10/10 [==============================] - 0s 1ms/step - loss: 0.2698 - accuracy: 0.8723
# Epoch 34/200
# 10/10 [==============================] - 0s 829us/step - loss: 0.2579 - accuracy: 0.9149
# Epoch 35/200
# 10/10 [==============================] - 0s 704us/step - loss: 0.2891 - accuracy: 0.8936
# Epoch 36/200
# 10/10 [==============================] - 0s 693us/step - loss: 0.2012 - accuracy: 0.9362
# Epoch 37/200
# 10/10 [==============================] - 0s 655us/step - loss: 0.3498 - accuracy: 0.9362
# Epoch 38/200
# 10/10 [==============================] - 0s 769us/step - loss: 0.2298 - accuracy: 0.9149
# Epoch 39/200
# 10/10 [==============================] - 0s 836us/step - loss: 0.1613 - accuracy: 0.9574
# Epoch 40/200
# 10/10 [==============================] - 0s 822us/step - loss: 0.1664 - accuracy: 0.9574
# Epoch 41/200
# 10/10 [==============================] - 0s 778us/step - loss: 0.1914 - accuracy: 0.9574
# Epoch 42/200
# 10/10 [==============================] - 0s 809us/step - loss: 0.2596 - accuracy: 0.9574
# Epoch 43/200
# 10/10 [==============================] - 0s 727us/step - loss: 0.1733 - accuracy: 0.9787
# Epoch 44/200
# 10/10 [==============================] - 0s 771us/step - loss: 0.1473 - accuracy: 0.9787
# Epoch 45/200
# 10/10 [==============================] - 0s 700us/step - loss: 0.1849 - accuracy: 0.9787
# Epoch 46/200
# 10/10 [==============================] - 0s 743us/step - loss: 0.0728 - accuracy: 1.0000
# Epoch 47/200
# 10/10 [==============================] - 0s 672us/step - loss: 0.2701 - accuracy: 0.9149
# Epoch 48/200
# 10/10 [==============================] - 0s 718us/step - loss: 0.1122 - accuracy: 0.9787
# Epoch 49/200
# 10/10 [==============================] - 0s 677us/step - loss: 0.0950 - accuracy: 0.9574
# Epoch 50/200
# 10/10 [==============================] - 0s 735us/step - loss: 0.0736 - accuracy: 1.0000
# Epoch 51/200
# 10/10 [==============================] - 0s 708us/step - loss: 0.1077 - accuracy: 0.9787
# Epoch 52/200
# 10/10 [==============================] - 0s 774us/step - loss: 0.0491 - accuracy: 1.0000
# Epoch 53/200
# 10/10 [==============================] - 0s 708us/step - loss: 0.0460 - accuracy: 1.0000
# Epoch 54/200
# 10/10 [==============================] - 0s 727us/step - loss: 0.1123 - accuracy: 0.9787
# Epoch 55/200
# 10/10 [==============================] - 0s 664us/step - loss: 0.1170 - accuracy: 0.9787
# Epoch 56/200
# 10/10 [==============================] - 0s 732us/step - loss: 0.0863 - accuracy: 1.0000
# Epoch 57/200
# 10/10 [==============================] - 0s 671us/step - loss: 0.1354 - accuracy: 0.9574
# Epoch 58/200
# 10/10 [==============================] - 0s 726us/step - loss: 0.1709 - accuracy: 0.9574
# Epoch 59/200
# 10/10 [==============================] - 0s 696us/step - loss: 0.1189 - accuracy: 0.9574
# Epoch 60/200
# 10/10 [==============================] - 0s 691us/step - loss: 0.0845 - accuracy: 0.9787
# Epoch 61/200
# 10/10 [==============================] - 0s 754us/step - loss: 0.1004 - accuracy: 0.9787
# Epoch 62/200
# 10/10 [==============================] - 0s 649us/step - loss: 0.0553 - accuracy: 0.9787
# Epoch 63/200
# 10/10 [==============================] - 0s 733us/step - loss: 0.0510 - accuracy: 1.0000
# Epoch 64/200
# 10/10 [==============================] - 0s 650us/step - loss: 0.0501 - accuracy: 1.0000
# Epoch 65/200
# 10/10 [==============================] - 0s 786us/step - loss: 0.0747 - accuracy: 0.9787
# Epoch 66/200
# 10/10 [==============================] - 0s 711us/step - loss: 0.0614 - accuracy: 1.0000
# Epoch 67/200
# 10/10 [==============================] - 0s 753us/step - loss: 0.0463 - accuracy: 1.0000
# Epoch 68/200
# 10/10 [==============================] - 0s 722us/step - loss: 0.1053 - accuracy: 0.9574
# Epoch 69/200
# 10/10 [==============================] - 0s 804us/step - loss: 0.1419 - accuracy: 0.9362
# Epoch 70/200
# 10/10 [==============================] - 0s 649us/step - loss: 0.0787 - accuracy: 0.9787
# Epoch 71/200
# 10/10 [==============================] - 0s 771us/step - loss: 0.0495 - accuracy: 1.0000
# Epoch 72/200
# 10/10 [==============================] - 0s 700us/step - loss: 0.0993 - accuracy: 0.9574
# Epoch 73/200
# 10/10 [==============================] - 0s 758us/step - loss: 0.0697 - accuracy: 1.0000
# Epoch 74/200
# 10/10 [==============================] - 0s 742us/step - loss: 0.0489 - accuracy: 0.9787
# Epoch 75/200
# 10/10 [==============================] - 0s 1ms/step - loss: 0.0456 - accuracy: 1.0000
# Epoch 76/200
# 10/10 [==============================] - 0s 711us/step - loss: 0.0797 - accuracy: 1.0000
# Epoch 77/200
# 10/10 [==============================] - 0s 663us/step - loss: 0.0550 - accuracy: 1.0000
# Epoch 78/200
# 10/10 [==============================] - 0s 656us/step - loss: 0.0550 - accuracy: 0.9787
# Epoch 79/200
# 10/10 [==============================] - 0s 724us/step - loss: 0.1806 - accuracy: 0.9362
# Epoch 80/200
# 10/10 [==============================] - 0s 710us/step - loss: 0.0346 - accuracy: 1.0000
# Epoch 81/200
# 10/10 [==============================] - 0s 776us/step - loss: 0.0922 - accuracy: 0.9787
# Epoch 82/200
# 10/10 [==============================] - 0s 786us/step - loss: 0.0546 - accuracy: 0.9787
# Epoch 83/200
# 10/10 [==============================] - 0s 776us/step - loss: 0.0903 - accuracy: 0.9787
# Epoch 84/200
# 10/10 [==============================] - 0s 740us/step - loss: 0.0639 - accuracy: 0.9787
# Epoch 85/200
# 10/10 [==============================] - 0s 729us/step - loss: 0.0325 - accuracy: 1.0000
# Epoch 86/200
# 10/10 [==============================] - 0s 756us/step - loss: 0.0306 - accuracy: 1.0000
# Epoch 87/200
# 10/10 [==============================] - 0s 675us/step - loss: 0.0852 - accuracy: 0.9787
# Epoch 88/200
# 10/10 [==============================] - 0s 746us/step - loss: 0.0136 - accuracy: 1.0000
# Epoch 89/200
# 10/10 [==============================] - 0s 660us/step - loss: 0.0701 - accuracy: 1.0000
# Epoch 90/200
# 10/10 [==============================] - 0s 694us/step - loss: 0.0553 - accuracy: 1.0000
# Epoch 91/200
# 10/10 [==============================] - 0s 775us/step - loss: 0.0627 - accuracy: 0.9787
# Epoch 92/200
# 10/10 [==============================] - 0s 741us/step - loss: 0.0186 - accuracy: 1.0000
# Epoch 93/200
# 10/10 [==============================] - 0s 739us/step - loss: 0.0792 - accuracy: 0.9787
# Epoch 94/200
# 10/10 [==============================] - 0s 724us/step - loss: 0.0529 - accuracy: 0.9787
# Epoch 95/200
# 10/10 [==============================] - 0s 765us/step - loss: 0.0374 - accuracy: 1.0000
# Epoch 96/200
# 10/10 [==============================] - 0s 756us/step - loss: 0.0278 - accuracy: 1.0000
# Epoch 97/200
# 10/10 [==============================] - 0s 664us/step - loss: 0.1035 - accuracy: 0.9787
# Epoch 98/200
# 10/10 [==============================] - 0s 737us/step - loss: 0.0209 - accuracy: 1.0000
# Epoch 99/200
# 10/10 [==============================] - 0s 677us/step - loss: 0.0625 - accuracy: 0.9787
# Epoch 100/200
# 10/10 [==============================] - 0s 700us/step - loss: 0.0387 - accuracy: 0.9787
# Epoch 101/200
# 10/10 [==============================] - 0s 751us/step - loss: 0.0372 - accuracy: 1.0000
# Epoch 102/200
# 10/10 [==============================] - 0s 732us/step - loss: 0.0351 - accuracy: 1.0000
# Epoch 103/200
# 10/10 [==============================] - 0s 739us/step - loss: 0.0709 - accuracy: 0.9574
# Epoch 104/200
# 10/10 [==============================] - 0s 720us/step - loss: 0.0193 - accuracy: 1.0000
# Epoch 105/200
# 10/10 [==============================] - 0s 646us/step - loss: 0.0378 - accuracy: 1.0000
# Epoch 106/200
# 10/10 [==============================] - 0s 723us/step - loss: 0.0245 - accuracy: 1.0000
# Epoch 107/200
# 10/10 [==============================] - 0s 1ms/step - loss: 0.0163 - accuracy: 1.0000
# Epoch 108/200
# 10/10 [==============================] - 0s 745us/step - loss: 0.0365 - accuracy: 1.0000
# Epoch 109/200
# 10/10 [==============================] - 0s 794us/step - loss: 0.0526 - accuracy: 1.0000
# Epoch 110/200
# 10/10 [==============================] - 0s 628us/step - loss: 0.0320 - accuracy: 1.0000
# Epoch 111/200
# 10/10 [==============================] - 0s 697us/step - loss: 0.0370 - accuracy: 1.0000
# Epoch 112/200
# 10/10 [==============================] - 0s 708us/step - loss: 0.0097 - accuracy: 1.0000
# Epoch 113/200
# 10/10 [==============================] - 0s 731us/step - loss: 0.0243 - accuracy: 1.0000
# Epoch 114/200
# 10/10 [==============================] - 0s 618us/step - loss: 0.0098 - accuracy: 1.0000
# Epoch 115/200
# 10/10 [==============================] - 0s 778us/step - loss: 0.0165 - accuracy: 1.0000
# Epoch 116/200
# 10/10 [==============================] - 0s 781us/step - loss: 0.0218 - accuracy: 1.0000
# Epoch 117/200
# 10/10 [==============================] - 0s 666us/step - loss: 0.0536 - accuracy: 0.9787
# Epoch 118/200
# 10/10 [==============================] - 0s 686us/step - loss: 0.0215 - accuracy: 1.0000
# Epoch 119/200
# 10/10 [==============================] - 0s 754us/step - loss: 0.0122 - accuracy: 1.0000
# Epoch 120/200
# 10/10 [==============================] - 0s 765us/step - loss: 0.0416 - accuracy: 1.0000
# Epoch 121/200
# 10/10 [==============================] - 0s 746us/step - loss: 0.0373 - accuracy: 1.0000
# Epoch 122/200
# 10/10 [==============================] - 0s 758us/step - loss: 0.0068 - accuracy: 1.0000
# Epoch 123/200
# 10/10 [==============================] - 0s 677us/step - loss: 0.0336 - accuracy: 1.0000
# Epoch 124/200
# 10/10 [==============================] - 0s 820us/step - loss: 0.0111 - accuracy: 1.0000
# Epoch 125/200
# 10/10 [==============================] - 0s 764us/step - loss: 0.0369 - accuracy: 1.0000
# Epoch 126/200
# 10/10 [==============================] - 0s 745us/step - loss: 0.0120 - accuracy: 1.0000
# Epoch 127/200
# 10/10 [==============================] - 0s 741us/step - loss: 0.0260 - accuracy: 1.0000
# Epoch 128/200
# 10/10 [==============================] - 0s 675us/step - loss: 0.0157 - accuracy: 1.0000
# Epoch 129/200
# 10/10 [==============================] - 0s 791us/step - loss: 0.1011 - accuracy: 0.9574
# Epoch 130/200
# 10/10 [==============================] - 0s 745us/step - loss: 0.0977 - accuracy: 0.9787
# Epoch 131/200
# 10/10 [==============================] - 0s 659us/step - loss: 0.0123 - accuracy: 1.0000
# Epoch 132/200
# 10/10 [==============================] - 0s 689us/step - loss: 0.0500 - accuracy: 0.9787
# Epoch 133/200
# 10/10 [==============================] - 0s 749us/step - loss: 0.0217 - accuracy: 1.0000
# Epoch 134/200
# 10/10 [==============================] - 0s 690us/step - loss: 0.0068 - accuracy: 1.0000
# Epoch 135/200
# 10/10 [==============================] - 0s 760us/step - loss: 0.0357 - accuracy: 1.0000
# Epoch 136/200
# 10/10 [==============================] - 0s 732us/step - loss: 0.0462 - accuracy: 0.9787
# Epoch 137/200
# 10/10 [==============================] - 0s 677us/step - loss: 0.0240 - accuracy: 0.9787
# Epoch 138/200
# 10/10 [==============================] - 0s 777us/step - loss: 0.0172 - accuracy: 1.0000
# Epoch 139/200
# 10/10 [==============================] - 0s 729us/step - loss: 0.0411 - accuracy: 0.9787
# Epoch 140/200
# 10/10 [==============================] - 0s 849us/step - loss: 0.0509 - accuracy: 1.0000
# Epoch 141/200
# 10/10 [==============================] - 0s 769us/step - loss: 0.0310 - accuracy: 1.0000
# Epoch 142/200
# 10/10 [==============================] - 0s 780us/step - loss: 0.0269 - accuracy: 1.0000
# Epoch 143/200
# 10/10 [==============================] - 0s 654us/step - loss: 0.0442 - accuracy: 0.9787
# Epoch 144/200
# 10/10 [==============================] - 0s 663us/step - loss: 0.0082 - accuracy: 1.0000
# Epoch 145/200
# 10/10 [==============================] - 0s 775us/step - loss: 0.0048 - accuracy: 1.0000
# Epoch 146/200
# 10/10 [==============================] - 0s 680us/step - loss: 0.0355 - accuracy: 1.0000
# Epoch 147/200
# 10/10 [==============================] - 0s 755us/step - loss: 0.0205 - accuracy: 1.0000
# Epoch 148/200
# 10/10 [==============================] - 0s 697us/step - loss: 0.0438 - accuracy: 1.0000
# Epoch 149/200
# 10/10 [==============================] - 0s 727us/step - loss: 0.0367 - accuracy: 0.9787
# Epoch 150/200
# 10/10 [==============================] - 0s 659us/step - loss: 0.0106 - accuracy: 1.0000
# Epoch 151/200
# 10/10 [==============================] - 0s 707us/step - loss: 0.0057 - accuracy: 1.0000
# Epoch 152/200
# 10/10 [==============================] - 0s 680us/step - loss: 0.0210 - accuracy: 1.0000
# Epoch 153/200
# 10/10 [==============================] - 0s 731us/step - loss: 0.0060 - accuracy: 1.0000
# Epoch 154/200
# 10/10 [==============================] - 0s 739us/step - loss: 0.0169 - accuracy: 1.0000
# Epoch 155/200
# 10/10 [==============================] - 0s 732us/step - loss: 0.0360 - accuracy: 1.0000
# Epoch 156/200
# 10/10 [==============================] - 0s 724us/step - loss: 0.0351 - accuracy: 1.0000
# Epoch 157/200
# 10/10 [==============================] - 0s 770us/step - loss: 0.0315 - accuracy: 1.0000
# Epoch 158/200
# 10/10 [==============================] - 0s 775us/step - loss: 0.0097 - accuracy: 1.0000
# Epoch 159/200
# 10/10 [==============================] - 0s 703us/step - loss: 0.0088 - accuracy: 1.0000
# Epoch 160/200
# 10/10 [==============================] - 0s 763us/step - loss: 0.0178 - accuracy: 1.0000
# Epoch 161/200
# 10/10 [==============================] - 0s 727us/step - loss: 0.0260 - accuracy: 0.9787
# Epoch 162/200
# 10/10 [==============================] - 0s 696us/step - loss: 0.0122 - accuracy: 1.0000
# Epoch 163/200
# 10/10 [==============================] - 0s 783us/step - loss: 0.0060 - accuracy: 1.0000
# Epoch 164/200
# 10/10 [==============================] - 0s 729us/step - loss: 0.0100 - accuracy: 1.0000
# Epoch 165/200
# 10/10 [==============================] - 0s 723us/step - loss: 0.0279 - accuracy: 1.0000
# Epoch 166/200
# 10/10 [==============================] - 0s 697us/step - loss: 0.0107 - accuracy: 1.0000
# Epoch 167/200
# 10/10 [==============================] - 0s 802us/step - loss: 0.0464 - accuracy: 0.9787
# Epoch 168/200
# 10/10 [==============================] - 0s 801us/step - loss: 0.0254 - accuracy: 0.9787
# Epoch 169/200
# 10/10 [==============================] - 0s 760us/step - loss: 0.0123 - accuracy: 1.0000
# Epoch 170/200
# 10/10 [==============================] - 0s 721us/step - loss: 0.0104 - accuracy: 1.0000
# Epoch 171/200
# 10/10 [==============================] - 0s 677us/step - loss: 0.0488 - accuracy: 1.0000
# Epoch 172/200
# 10/10 [==============================] - 0s 806us/step - loss: 0.0039 - accuracy: 1.0000
# Epoch 173/200
# 10/10 [==============================] - 0s 697us/step - loss: 0.0141 - accuracy: 1.0000
# Epoch 174/200
# 10/10 [==============================] - 0s 615us/step - loss: 0.0411 - accuracy: 0.9787
# Epoch 175/200
# 10/10 [==============================] - 0s 709us/step - loss: 0.0154 - accuracy: 1.0000
# Epoch 176/200
# 10/10 [==============================] - 0s 789us/step - loss: 0.0273 - accuracy: 0.9787
# Epoch 177/200
# 10/10 [==============================] - 0s 759us/step - loss: 0.0349 - accuracy: 1.0000
# Epoch 178/200
# 10/10 [==============================] - 0s 755us/step - loss: 0.0318 - accuracy: 1.0000
# Epoch 179/200
# 10/10 [==============================] - 0s 752us/step - loss: 0.0160 - accuracy: 1.0000
# Epoch 180/200
# 10/10 [==============================] - 0s 672us/step - loss: 0.0522 - accuracy: 0.9787
# Epoch 181/200
# 10/10 [==============================] - 0s 876us/step - loss: 0.0194 - accuracy: 1.0000
# Epoch 182/200
# 10/10 [==============================] - 0s 777us/step - loss: 0.0321 - accuracy: 1.0000
# Epoch 183/200
# 10/10 [==============================] - 0s 759us/step - loss: 0.0083 - accuracy: 1.0000
# Epoch 184/200
# 10/10 [==============================] - 0s 719us/step - loss: 0.0231 - accuracy: 1.0000
# Epoch 185/200
# 10/10 [==============================] - 0s 802us/step - loss: 0.0538 - accuracy: 0.9787
# Epoch 186/200
# 10/10 [==============================] - 0s 652us/step - loss: 0.0068 - accuracy: 1.0000
# Epoch 187/200
# 10/10 [==============================] - 0s 733us/step - loss: 0.0087 - accuracy: 1.0000
# Epoch 188/200
# 10/10 [==============================] - 0s 716us/step - loss: 0.0092 - accuracy: 1.0000
# Epoch 189/200
# 10/10 [==============================] - 0s 655us/step - loss: 0.0172 - accuracy: 1.0000
# Epoch 190/200
# 10/10 [==============================] - 0s 756us/step - loss: 0.0230 - accuracy: 1.0000
# Epoch 191/200
# 10/10 [==============================] - 0s 751us/step - loss: 0.0078 - accuracy: 1.0000
# Epoch 192/200
# 10/10 [==============================] - 0s 810us/step - loss: 0.0242 - accuracy: 1.0000
# Epoch 193/200
# 10/10 [==============================] - 0s 745us/step - loss: 0.0444 - accuracy: 0.9787
# Epoch 194/200
# 10/10 [==============================] - 0s 774us/step - loss: 0.0088 - accuracy: 1.0000
# Epoch 195/200
# 10/10 [==============================] - 0s 690us/step - loss: 0.0166 - accuracy: 1.0000
# Epoch 196/200
# 10/10 [==============================] - 0s 687us/step - loss: 0.0136 - accuracy: 1.0000
# Epoch 197/200
# 10/10 [==============================] - 0s 710us/step - loss: 0.0198 - accuracy: 1.0000
# Epoch 198/200
# 10/10 [==============================] - 0s 660us/step - loss: 0.0166 - accuracy: 1.0000
# Epoch 199/200
# 10/10 [==============================] - 0s 779us/step - loss: 0.0213 - accuracy: 1.0000
# Epoch 200/200
# 10/10 [==============================] - 0s 636us/step - loss: 0.0402 - accuracy: 1.0000

# %%
model.save('chatbot_Application_model.h5', history)
# Out:
# /home/mrityunjay/anaconda3/lib/python3.11/site-packages/keras/src/engine/training.py:3103: UserWarning: You are saving your model as an HDF5 file via `model.save()`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')`.
#   saving_api.save_model(
